# %%
import numpy as np
import pandas as pd
from datetime import datetime
from sklearn.model_selection import cross_val_score         #用随机森林进行特征选择
from sklearn.linear_model import Ridge                      #线性回归模型
#import lightgbm as lgb
from sklearn.model_selection import train_test_split        #
import xgboost as xgb 
from xgboost import plot_importance                         #用xgb的方法进行特征重要性筛选

# %%
#读取数据集
train_df = pd.read_csv("../input/train_data.csv",index_col=0)
test_df = pd.read_csv("../input/test_a.csv",index_col=0)

# %%
#feat_labels = train_df.columns[0:2]
#feat_labels.head()

# %%
train_df.head(5)
#train_df.shape
# Out:
#              area rentType houseType houseFloor  totalFloor houseToward  \
# ID
# 100309852   68.06     未知方式    2室1厅1卫          低          16        暂无数据
# 100307942  125.55     未知方式    3室2厅2卫          中          14        暂无数据
# 100307764  132.00     未知方式    3室2厅2卫          低          32        暂无数据
# 100306518   57.00     未知方式    1室1厅1卫          中          17        暂无数据
# 100305262  129.00     未知方式    3室2厅3卫          低           2        暂无数据
#
#           houseDecoration communityName city   region     ...      \
# ID                                                        ...
# 100309852              其他       XQ00051   SH  RG00001     ...
# 100307942              简装       XQ00130   SH  RG00002     ...
# 100307764              其他       XQ00179   SH  RG00002     ...
# 100306518              精装       XQ00313   SH  RG00002     ...
# 100305262              毛坯       XQ01257   SH  RG00003     ...
#
#           landTotalPrice landMeanPrice  totalWorkers  newWorkers  \
# ID
# 100309852              0        0.0000         28248         614
# 100307942              0        0.0000         14823         148
# 100307764              0        0.0000         77645         520
# 100306518      332760000     3080.0331          8750        1665
# 100305262              0        0.0000           800         117
#
#            residentPopulation      pv     uv  lookNum   tradeTime  tradeMoney
# ID
# 100309852              111546  1124.0  284.0        0  2018/11/28      2000.0
# 100307942              157552   701.0   22.0        1  2018/12/16      2000.0
# 100307764              131744    57.0   20.0        1  2018/12/22     16000.0
# 100306518              253337   888.0  279.0        9  2018/12/21      1600.0
# 100305262              125309  2038.0  480.0        0  2018/11/18      2900.0
#
# [5 rows x 50 columns]

# %%
#test_df.head(10)
#test_df.shape

# %%
train_df["tradeMoney"].sort_values(ascending =True).head(10)      #true表示升序,false表示降序
# Out:
# ID
# 100279227      0.0
# 100090432      0.0
# 100304665      0.0
# 100302973      0.0
# 100304683      0.0
# 100073193      0.0
# 100276327      0.0
# 100281933      0.0
# 100305713      0.0
# 100020818    100.0
# Name: tradeMoney, dtype: float64

# %%
#查看一下tradeMoney值分布情况
train_df["tradeMoney"].sort_values(ascending =False).head(10)
# Out:
# ID
# 100007093    99999999.99
# 100028451    50000000.00
# 100042658    10000000.00
# 100022073      450000.00
# 100047710      450000.00
# 100084542      450000.00
# 100310820      450000.00
# 100012093      430000.00
# 100083675      380000.00
# 100089204      370000.00
# Name: tradeMoney, dtype: float64

# %% [markdown]
# tradeMoney有离群点,对该列特征进行处理

# %%
#mean_tradeMoney = train_df["tradeMoney"].mean()
#train_df.loc[train_df["tradeMoney"] == 99999999.99,"tradeMoney"] = mean_tradeMoney
#train_df.loc[train_df["tradeMoney"] == 50000000.00,"tradeMoney"] = mean_tradeMoney
#train_df.loc[train_df["tradeMoney"] == 10000000.00,"tradeMoney"] = mean_tradeMoney

# %% [markdown]
# 筛选交易额在100-10w之间的数据

# %%
#处理训练集中"tradeMoney"中的异常点
train_data = train_df[(train_df["tradeMoney"]>100)&(train_df["tradeMoney"]<100000)].copy()
print(train_data.shape[0])
# Out:
# 41410

# %%
#处理训练集中"area"的异常点
#查看楼层
#train_df["totalFloor"].unique()
#发现有0层的,所以对totalFloor进行异常处理
train_1 = train_data[(train_data["area"]>10)&(train_data["area"]<1000)&(train_data["totalFloor"]>0)].copy()
#处理测试集中"area"的异常点
test_1 = test_df[(test_df["area"] > 10 ) &(test_df["area"]<1000)&(test_df["totalFloor"]>0)].copy()

# %%
y_train = train_1["tradeMoney"].copy()
y_train.shape[0]
# Out:
# 40072

# %% [markdown]
# 由此可见 测试集比训练集少了一列特征"tradeMoney",这就是我们测试集所要预测的label值

# %%
train_1.drop('tradeMoney',axis=1, inplace=True) 
train_1.shape[0]
# Out:
# 40072

# %% [markdown]
# 合并训练集和测试集,以方便进行处理

# %%
all_df = pd.concat((train_1, test_1), axis=0)

# %% [markdown]
# to_datetime函数用法

# %%
all_df["tradeTime1"]  =pd.to_datetime(all_df["tradeTime"])
all_df["tradeTime"].head()
# Out:
# ID
# 100309852    2018/11/28
# 100307942    2018/12/16
# 100307764    2018/12/22
# 100306518    2018/12/21
# 100305262    2018/11/18
# Name: tradeTime, dtype: object

# %% [markdown]
# split函数用法

# %%
#all_df["trade_time"] = all_df["tradeTime"].apply(lambda x: x.split("/"))    
#all_df["trade_time"].head()

# %%
all_df["trade_time"] = all_df.tradeTime.astype(str).apply(lambda x:int(x[0:4]))
all_df["trade_time"].astype(int)
all_df.head()
# Out:
#              area rentType houseType houseFloor  totalFloor houseToward  \
# ID
# 100309852   68.06     未知方式    2室1厅1卫          低          16        暂无数据
# 100307942  125.55     未知方式    3室2厅2卫          中          14        暂无数据
# 100307764  132.00     未知方式    3室2厅2卫          低          32        暂无数据
# 100306518   57.00     未知方式    1室1厅1卫          中          17        暂无数据
# 100305262  129.00     未知方式    3室2厅3卫          低           2        暂无数据
#
#           houseDecoration communityName city   region     ...      \
# ID                                                        ...
# 100309852              其他       XQ00051   SH  RG00001     ...
# 100307942              简装       XQ00130   SH  RG00002     ...
# 100307764              其他       XQ00179   SH  RG00002     ...
# 100306518              精装       XQ00313   SH  RG00002     ...
# 100305262              毛坯       XQ01257   SH  RG00003     ...
#
#           landMeanPrice totalWorkers  newWorkers  residentPopulation      pv  \
# ID
# 100309852        0.0000        28248         614              111546  1124.0
# 100307942        0.0000        14823         148              157552   701.0
# 100307764        0.0000        77645         520              131744    57.0
# 100306518     3080.0331         8750        1665              253337   888.0
# 100305262        0.0000          800         117              125309  2038.0
#
#               uv  lookNum   tradeTime  tradeTime1  trade_time
# ID
# 100309852  284.0        0  2018/11/28  2018-11-28        2018
# 100307942   22.0        1  2018/12/16  2018-12-16        2018
# 100307764   20.0        1  2018/12/22  2018-12-22        2018
# 100306518  279.0        9  2018/12/21  2018-12-21        2018
# 100305262  480.0        0  2018/11/18  2018-11-18        2018
#
# [5 rows x 51 columns]

# %%
print(all_df["trade_time"].dtypes)
print(all_df["buildYear"].dtypes)
# Out:
# int64
# object

# %%
all_df.shape
# Out:
# (42541, 51)

# %%
#all_df.info()  #由此可见,除了"uv"特征和"pv"特征缺失20个以外,其他的不存在空的特征,因此无需对数据集进行填充.
all_df.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# uv                  20
# pv                  20
# trade_time           0
# buildYear            0
# bankNum              0
# gymNum               0
# drugStoreNum         0
# hospitalNum          0
# privateSchoolNum     0
# schoolNum            0
# dtype: int64

# %%
all_df["rentType"].value_counts()
# Out:
# 未知方式    32900
# 整租       5728
# 合租       3908
# --          5
# Name: rentType, dtype: int64

# %%
all_df.head()
# Out:
#              area rentType houseType houseFloor  totalFloor houseToward  \
# ID
# 100309852   68.06     未知方式    2室1厅1卫          低          16        暂无数据
# 100307942  125.55     未知方式    3室2厅2卫          中          14        暂无数据
# 100307764  132.00     未知方式    3室2厅2卫          低          32        暂无数据
# 100306518   57.00     未知方式    1室1厅1卫          中          17        暂无数据
# 100305262  129.00     未知方式    3室2厅3卫          低           2        暂无数据
#
#           houseDecoration communityName city   region     ...      \
# ID                                                        ...
# 100309852              其他       XQ00051   SH  RG00001     ...
# 100307942              简装       XQ00130   SH  RG00002     ...
# 100307764              其他       XQ00179   SH  RG00002     ...
# 100306518              精装       XQ00313   SH  RG00002     ...
# 100305262              毛坯       XQ01257   SH  RG00003     ...
#
#           landMeanPrice totalWorkers  newWorkers  residentPopulation      pv  \
# ID
# 100309852        0.0000        28248         614              111546  1124.0
# 100307942        0.0000        14823         148              157552   701.0
# 100307764        0.0000        77645         520              131744    57.0
# 100306518     3080.0331         8750        1665              253337   888.0
# 100305262        0.0000          800         117              125309  2038.0
#
#               uv  lookNum   tradeTime  tradeTime1  trade_time
# ID
# 100309852  284.0        0  2018/11/28  2018-11-28        2018
# 100307942   22.0        1  2018/12/16  2018-12-16        2018
# 100307764   20.0        1  2018/12/22  2018-12-22        2018
# 100306518  279.0        9  2018/12/21  2018-12-21        2018
# 100305262  480.0        0  2018/11/18  2018-11-18        2018
#
# [5 rows x 51 columns]

# %%
all_df["houseType"].unique()  #查看一下,一共有多少种类型
# Out:
# array(['2室1厅1卫', '3室2厅2卫', '1室1厅1卫', '3室2厅3卫', '4室3厅3卫', '2室2厅1卫',
#        '3室2厅1卫', '3室1厅1卫', '5室2厅3卫', '2室1厅2卫', '4室2厅2卫', '1室0厅1卫',
#        '4室2厅3卫', '1室0厅0卫', '2室2厅2卫', '2室0厅1卫', '1室2厅1卫', '6室3厅4卫',
#        '4室2厅4卫', '4室2厅1卫', '5室3厅5卫', '4室3厅2卫', '6室3厅2卫', '5室2厅2卫',
#        '5室2厅4卫', '1室1厅2卫', '4室1厅3卫', '3室0厅1卫', '5室5厅4卫', '4室3厅5卫',
#        '4室3厅4卫', '0室0厅1卫', '5室2厅5卫', '7室2厅3卫', '3室2厅4卫', '3室3厅2卫',
#        '3室1厅2卫', '5室3厅4卫', '5室4厅5卫', '5室3厅3卫', '5室2厅6卫', '5室3厅1卫',
#        '3室4厅4卫', '6室2厅4卫', '6室1厅4卫', '3室1厅3卫', '6室2厅3卫', '5室4厅3卫',
#        '2室2厅3卫', '4室1厅1卫', '5室1厅1卫', '1室2厅2卫', '6室1厅1卫', '4室1厅2卫',
#        '5室3厅6卫', '4室2厅5卫', '6室2厅2卫', '5室1厅2卫', '5室4厅4卫', '2室3厅1卫',
#        '6室4厅2卫', '7室1厅7卫', '3室3厅4卫', '3室2厅5卫', '6室3厅5卫', '4室0厅1卫',
#        '5室4厅2卫', '7室4厅3卫', '6室3厅3卫', '6室2厅5卫', '6室2厅7卫', '4室0厅4卫',
#        '2室2厅0卫', '3室3厅3卫', '8室3厅4卫', '6室2厅6卫', '1室1厅0卫', '2室1厅0卫',
#        '5室3厅2卫', '5室2厅1卫', '2室0厅0卫', '6室2厅1卫', '8室2厅4卫', '7室1厅1卫',
#        '7室2厅1卫', '2室0厅2卫', '3室0厅2卫', '4室0厅2卫', '3室1厅0卫', '3室0厅0卫',
#        '9室2厅5卫', '6室4厅5卫', '4室4厅2卫', '4室1厅4卫', '8室4厅4卫', '7室2厅4卫',
#        '7室1厅3卫', '8室2厅3卫', '7室3厅4卫', '5室1厅5卫', '2室1厅3卫', '6室4厅4卫',
#        '5室1厅3卫', '9室3厅8卫', '1室2厅0卫', '3室2厅0卫', '6室0厅6卫'], dtype=object)

# %% [markdown]
# 查看数据集的函数: head,  info,  unique,  describe,  sort_values(),  value_counts(),  dtypes()

# %%
#特征处理:"houseFloor"
all_df["houseFloor"].unique()
# Out:
# array(['低', '中', '高'], dtype=object)

# %%
#用replace替换得到的1,2,3是object类型
#all_df["houseFloor"] =all_df["houseFloor"].replace("低",1)
#all_df["houseFloor"] =all_df["houseFloor"].replace("中",2)
#all_df["houseFloor"] =all_df["houseFloor"].replace("高",3)
all_df.loc[all_df["houseFloor"] == "低","houseFloor"] = 0
all_df.loc[all_df["houseFloor"] == "中","houseFloor"] = 1
all_df.loc[all_df["houseFloor"] == "高","houseFloor"] = 2
all_df["houseFloor"].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
#提取特征三:"totalFloor
all_df["totalFloor"].unique()
# Out:
# array([16, 14, 32, 17,  2, 18,  5,  6,  7, 21,  1,  3, 19, 29, 12,  8,  4,
#        22, 30, 20, 24, 25, 26, 28, 15, 10, 11, 13, 33,  9, 23, 37, 27, 56,
#        38, 40, 60, 35, 49, 41, 31, 62, 36, 53, 59, 39, 43, 61, 58, 51, 45,
#        47, 34, 88], dtype=int64)

# %%
all_df["houseToward"].value_counts()
#没法处理暂时舍去
#all_df.drop('houseToward',axis=1, inplace=True) 
all_df["houseToward"]=all_df["houseToward"].replace("暂无数据","南")
all_df["houseToward"].value_counts()
# Out:
# 南     36709
# 南北     2781
# 北      1263
# 东南      655
# 东       500
# 西南      320
# 西       223
# 西北       66
# 东西       24
# Name: houseToward, dtype: int64

# %%
all_df["houseDecoration"].value_counts()  
#缺失值有点多,这个特征比较重要,但是目前没法处理,暂时舍去
# Out:
# 其他    30978
# 精装     9966
# 简装     1270
# 毛坯      327
# Name: houseDecoration, dtype: int64

# %%
#all_df.drop('houseDecoration',axis=1, inplace=True)

# %%
all_df.head()
# Out:
#              area rentType houseType  houseFloor  totalFloor houseToward  \
# ID
# 100309852   68.06     未知方式    2室1厅1卫           0          16           南
# 100307942  125.55     未知方式    3室2厅2卫           1          14           南
# 100307764  132.00     未知方式    3室2厅2卫           0          32           南
# 100306518   57.00     未知方式    1室1厅1卫           1          17           南
# 100305262  129.00     未知方式    3室2厅3卫           0           2           南
#
#           houseDecoration communityName city   region     ...      \
# ID                                                        ...
# 100309852              其他       XQ00051   SH  RG00001     ...
# 100307942              简装       XQ00130   SH  RG00002     ...
# 100307764              其他       XQ00179   SH  RG00002     ...
# 100306518              精装       XQ00313   SH  RG00002     ...
# 100305262              毛坯       XQ01257   SH  RG00003     ...
#
#           landMeanPrice totalWorkers  newWorkers  residentPopulation      pv  \
# ID
# 100309852        0.0000        28248         614              111546  1124.0
# 100307942        0.0000        14823         148              157552   701.0
# 100307764        0.0000        77645         520              131744    57.0
# 100306518     3080.0331         8750        1665              253337   888.0
# 100305262        0.0000          800         117              125309  2038.0
#
#               uv  lookNum   tradeTime  tradeTime1  trade_time
# ID
# 100309852  284.0        0  2018/11/28  2018-11-28        2018
# 100307942   22.0        1  2018/12/16  2018-12-16        2018
# 100307764   20.0        1  2018/12/22  2018-12-22        2018
# 100306518  279.0        9  2018/12/21  2018-12-21        2018
# 100305262  480.0        0  2018/11/18  2018-11-18        2018
#
# [5 rows x 51 columns]

# %%
#all_df["communityName"].value_counts()   
#特征没法处理,暂时舍去
all_df.drop('communityName',axis=1, inplace=True)

# %%
#all_df["city"].value_counts()
#由此可见,city只有一种,所以可以直接删去
all_df.drop('city',axis=1, inplace=True)

# %%
all_df.head()
# Out:
#              area rentType houseType  houseFloor  totalFloor houseToward  \
# ID
# 100309852   68.06     未知方式    2室1厅1卫           0          16           南
# 100307942  125.55     未知方式    3室2厅2卫           1          14           南
# 100307764  132.00     未知方式    3室2厅2卫           0          32           南
# 100306518   57.00     未知方式    1室1厅1卫           1          17           南
# 100305262  129.00     未知方式    3室2厅3卫           0           2           南
#
#           houseDecoration   region    plate buildYear     ...      \
# ID                                                        ...
# 100309852              其他  RG00001  BK00064      1953     ...
# 100307942              简装  RG00002  BK00049      2007     ...
# 100307764              其他  RG00002  BK00050      暂无信息     ...
# 100306518              精装  RG00002  BK00051      暂无信息     ...
# 100305262              毛坯  RG00003  BK00044      暂无信息     ...
#
#            landMeanPrice  totalWorkers  newWorkers  residentPopulation  \
# ID
# 100309852         0.0000         28248         614              111546
# 100307942         0.0000         14823         148              157552
# 100307764         0.0000         77645         520              131744
# 100306518      3080.0331          8750        1665              253337
# 100305262         0.0000           800         117              125309
#
#                pv     uv  lookNum   tradeTime  tradeTime1  trade_time
# ID
# 100309852  1124.0  284.0        0  2018/11/28  2018-11-28        2018
# 100307942   701.0   22.0        1  2018/12/16  2018-12-16        2018
# 100307764    57.0   20.0        1  2018/12/22  2018-12-22        2018
# 100306518   888.0  279.0        9  2018/12/21  2018-12-21        2018
# 100305262  2038.0  480.0        0  2018/11/18  2018-11-18        2018
#
# [5 rows x 49 columns]

# %% [markdown]
# 提取特征六:"region",直接one_hot处理

# %%
#all_df["region"].value_counts()

# %% [markdown]
# 提取特征七:"plate"

# %%
all_df["plate"].unique()
# Out:
# array(['BK00064', 'BK00049', 'BK00050', 'BK00051', 'BK00044', 'BK00052',
#        'BK00031', 'BK00028', 'BK00017', 'BK00045', 'BK00027', 'BK00041',
#        'BK00047', 'BK00009', 'BK00025', 'BK00024', 'BK00014', 'BK00026',
#        'BK00042', 'BK00046', 'BK00043', 'BK00013', 'BK00012', 'BK00005',
#        'BK00011', 'BK00010', 'BK00003', 'BK00033', 'BK00053', 'BK00006',
#        'BK00004', 'BK00002', 'BK00007', 'BK00015', 'BK00016', 'BK00019',
#        'BK00030', 'BK00048', 'BK00018', 'BK00008', 'BK00029', 'BK00065',
#        'BK00035', 'BK00036', 'BK00022', 'BK00023', 'BK00054', 'BK00038',
#        'BK00037', 'BK00034', 'BK00058', 'BK00066', 'BK00039', 'BK00057',
#        'BK00020', 'BK00059', 'BK00060', 'BK00063', 'BK00055', 'BK00061',
#        'BK00040', 'BK00056', 'BK00062', 'BK00021', 'BK00032', 'BK00001'],
#       dtype=object)

# %% [markdown]
# 提取特征八:"buildYear"

# %%
all_df.loc[all_df["buildYear"] == "暂无信息","buildYear"] = 0

# %%
#all_df["buildYear"].value_counts()
all_df["buildYear"] =all_df["buildYear"].astype(int)
mean_col = all_df["buildYear"].mean()
print("-----------------------------------")
all_df["buildYear"] = all_df["buildYear"].replace(0,mean_col).astype(int)
all_df["buildYear"].unique()
# Out:
# -----------------------------------
# array([1953, 2007, 1870, 2003, 2014, 1997, 1993, 1994, 1998, 2000, 1995,
#        1999, 2015, 1981, 2002, 2010, 2011, 1989, 1983, 2001, 2012, 1996,
#        2004, 2006, 2009, 2008, 1984, 2017, 1976, 1986, 1988, 1992, 2005,
#        1987, 2016, 1965, 1990, 1985, 1978, 2013, 1980, 1954, 1982, 1968,
#        1940, 1966, 1970, 1937, 1979, 1974, 1964, 1991, 1977, 1956, 1930,
#        1952, 1957, 1936, 1967, 1972, 1975, 1955, 1949, 1912, 1958, 1973,
#        1932, 1963, 1931, 1926, 1939, 1951, 1960, 1910, 1969, 1920, 1959,
#        1962, 1961, 1950], dtype=int64)

# %%
all_df["trade_build"] =all_df["trade_time"] - all_df["buildYear"]
all_df.head()
# Out:
#              area rentType houseType  houseFloor  totalFloor houseToward  \
# ID
# 100309852   68.06     未知方式    2室1厅1卫           0          16           南
# 100307942  125.55     未知方式    3室2厅2卫           1          14           南
# 100307764  132.00     未知方式    3室2厅2卫           0          32           南
# 100306518   57.00     未知方式    1室1厅1卫           1          17           南
# 100305262  129.00     未知方式    3室2厅3卫           0           2           南
#
#           houseDecoration   region    plate  buildYear     ...       \
# ID                                                         ...
# 100309852              其他  RG00001  BK00064       1953     ...
# 100307942              简装  RG00002  BK00049       2007     ...
# 100307764              其他  RG00002  BK00050       1870     ...
# 100306518              精装  RG00002  BK00051       1870     ...
# 100305262              毛坯  RG00003  BK00044       1870     ...
#
#            totalWorkers  newWorkers  residentPopulation      pv     uv  \
# ID
# 100309852         28248         614              111546  1124.0  284.0
# 100307942         14823         148              157552   701.0   22.0
# 100307764         77645         520              131744    57.0   20.0
# 100306518          8750        1665              253337   888.0  279.0
# 100305262           800         117              125309  2038.0  480.0
#
#            lookNum   tradeTime  tradeTime1  trade_time  trade_build
# ID
# 100309852        0  2018/11/28  2018-11-28        2018           65
# 100307942        1  2018/12/16  2018-12-16        2018           11
# 100307764        1  2018/12/22  2018-12-22        2018          148
# 100306518        9  2018/12/21  2018-12-21        2018          148
# 100305262        0  2018/11/18  2018-11-18        2018          148
#
# [5 rows x 50 columns]

# %%
#all_df["pv"].value_counts()

# %%
#all_df = pd.to_datetime(all_df["tradeTime"], format='%Y-%m-%d')
all_df["shi"] = all_df.houseType.astype('str').apply(lambda x:int(x[0:1]))
all_df["ting"] = all_df.houseType.astype('str').apply(lambda x:int(x[2:3]))
all_df["wei"] = all_df.houseType.astype('str').apply(lambda x:int(x[4:5]))

all_df.head()
# Out:
#              area rentType houseType  houseFloor  totalFloor houseToward  \
# ID
# 100309852   68.06     未知方式    2室1厅1卫           0          16           南
# 100307942  125.55     未知方式    3室2厅2卫           1          14           南
# 100307764  132.00     未知方式    3室2厅2卫           0          32           南
# 100306518   57.00     未知方式    1室1厅1卫           1          17           南
# 100305262  129.00     未知方式    3室2厅3卫           0           2           南
#
#           houseDecoration   region    plate  buildYear ...       pv     uv  \
# ID                                                     ...
# 100309852              其他  RG00001  BK00064       1953 ...   1124.0  284.0
# 100307942              简装  RG00002  BK00049       2007 ...    701.0   22.0
# 100307764              其他  RG00002  BK00050       1870 ...     57.0   20.0
# 100306518              精装  RG00002  BK00051       1870 ...    888.0  279.0
# 100305262              毛坯  RG00003  BK00044       1870 ...   2038.0  480.0
#
#            lookNum   tradeTime  tradeTime1  trade_time  trade_build  shi  \
# ID
# 100309852        0  2018/11/28  2018-11-28        2018           65    2
# 100307942        1  2018/12/16  2018-12-16        2018           11    3
# 100307764        1  2018/12/22  2018-12-22        2018          148    3
# 100306518        9  2018/12/21  2018-12-21        2018          148    1
# 100305262        0  2018/11/18  2018-11-18        2018          148    3
#
#            ting  wei
# ID
# 100309852     1    1
# 100307942     2    2
# 100307764     2    2
# 100306518     1    1
# 100305262     2    3
#
# [5 rows x 53 columns]

# %% [markdown]
# 后边特征都是数值型,不需要进行one_hot处理,只需处理日期和填补缺失值

# %%
#all_df["uv"].describe()
all_df["uv"] = all_df["uv"].fillna(all_df["uv"].mean())
#all_df["pv"].dtypes
all_df["pv"] = all_df["pv"].fillna(all_df["pv"].mean())
all_df.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# wei               0
# totalTradeArea    0
# superMarketNum    0
# mallNum           0
# parkNum           0
# shopNum           0
# bankNum           0
# gymNum            0
# drugStoreNum      0
# hospitalNum       0
# dtype: int64

# %%
def get_rate(row1,row2):
    return  row1/row2
    
all_df["pvuv"] = get_rate(all_df["pv"],all_df["uv"])
all_df.head()
# Out:
#              area rentType houseType  houseFloor  totalFloor houseToward  \
# ID
# 100309852   68.06     未知方式    2室1厅1卫           0          16           南
# 100307942  125.55     未知方式    3室2厅2卫           1          14           南
# 100307764  132.00     未知方式    3室2厅2卫           0          32           南
# 100306518   57.00     未知方式    1室1厅1卫           1          17           南
# 100305262  129.00     未知方式    3室2厅3卫           0           2           南
#
#           houseDecoration   region    plate  buildYear    ...         uv  \
# ID                                                        ...
# 100309852              其他  RG00001  BK00064       1953    ...      284.0
# 100307942              简装  RG00002  BK00049       2007    ...       22.0
# 100307764              其他  RG00002  BK00050       1870    ...       20.0
# 100306518              精装  RG00002  BK00051       1870    ...      279.0
# 100305262              毛坯  RG00003  BK00044       1870    ...      480.0
#
#            lookNum   tradeTime  tradeTime1  trade_time  trade_build  shi  \
# ID
# 100309852        0  2018/11/28  2018-11-28        2018           65    2
# 100307942        1  2018/12/16  2018-12-16        2018           11    3
# 100307764        1  2018/12/22  2018-12-22        2018          148    3
# 100306518        9  2018/12/21  2018-12-21        2018          148    1
# 100305262        0  2018/11/18  2018-11-18        2018          148    3
#
#            ting  wei       pvuv
# ID
# 100309852     1    1   3.957746
# 100307942     2    2  31.863636
# 100307764     2    2   2.850000
# 100306518     1    1   3.182796
# 100305262     2    3   4.245833
#
# [5 rows x 54 columns]

# %%
#日期很重要,但是暂时不知道怎么处理,后期再说
#all_df["tradeTime"] = pd.to_datetime(all_df["tradeTime"],format ="%Y/%m/%d")
#all_df["tradeTime"] = pd.to_datetime(all_df['tradeTime'],infer_datetime_format=True)

# %%
all_df.head()
# Out:
#              area rentType houseType  houseFloor  totalFloor houseToward  \
# ID
# 100309852   68.06     未知方式    2室1厅1卫           0          16           南
# 100307942  125.55     未知方式    3室2厅2卫           1          14           南
# 100307764  132.00     未知方式    3室2厅2卫           0          32           南
# 100306518   57.00     未知方式    1室1厅1卫           1          17           南
# 100305262  129.00     未知方式    3室2厅3卫           0           2           南
#
#           houseDecoration   region    plate  buildYear    ...         uv  \
# ID                                                        ...
# 100309852              其他  RG00001  BK00064       1953    ...      284.0
# 100307942              简装  RG00002  BK00049       2007    ...       22.0
# 100307764              其他  RG00002  BK00050       1870    ...       20.0
# 100306518              精装  RG00002  BK00051       1870    ...      279.0
# 100305262              毛坯  RG00003  BK00044       1870    ...      480.0
#
#            lookNum   tradeTime  tradeTime1  trade_time  trade_build  shi  \
# ID
# 100309852        0  2018/11/28  2018-11-28        2018           65    2
# 100307942        1  2018/12/16  2018-12-16        2018           11    3
# 100307764        1  2018/12/22  2018-12-22        2018          148    3
# 100306518        9  2018/12/21  2018-12-21        2018          148    1
# 100305262        0  2018/11/18  2018-11-18        2018          148    3
#
#            ting  wei       pvuv
# ID
# 100309852     1    1   3.957746
# 100307942     2    2  31.863636
# 100307764     2    2   2.850000
# 100306518     1    1   3.182796
# 100305262     2    3   4.245833
#
# [5 rows x 54 columns]

# %%
print(y_train.shape[0])
# Out:
# 40072

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
x, y = train_data.iloc[:, 12:45].values, train_data.iloc[:, 48].values

x_train, x_test, Y_train, Y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)
feat_labels = train_df.columns[12:45]
forest = RandomForestClassifier(n_estimators=10, random_state=0, n_jobs=-1)
forest.fit(x_train, Y_train)


importances = forest.feature_importances_
indices = np.argsort(importances)[::-1]
for f in range(x_train.shape[1]):
    print("%2d) %-*s %f" % (f + 1, 30, feat_labels[indices[f]], importances[indices[f]]))

#print(x_train.shape[1])
# Out:
#  1) saleSecHouseNum                0.444394
#  2) totalTradeArea                 0.048244
#  3) totalTradeMoney                0.047379
#  4) tradeMeanPrice                 0.041838
#  5) tradeSecNum                    0.041452
#  6) remainNewNum                   0.034013
#  7) totalNewTradeMoney             0.031503
#  8) totalNewTradeArea              0.031276
#  9) tradeNewMeanPrice              0.029020
# 10) tradeNewNum                    0.028492
# 11) newWorkers                     0.024710
# 12) gymNum                         0.014158
# 13) busStationNum                  0.013296
# 14) supplyNewNum                   0.012846
# 15) totalWorkers                   0.012330
# 16) residentPopulation             0.011477
# 17) superMarketNum                 0.011244
# 18) hospitalNum                    0.011205
# 19) schoolNum                      0.011195
# 20) drugStoreNum                   0.011012
# 21) parkNum                        0.010402
# 22) shopNum                        0.010195
# 23) privateSchoolNum               0.010140
# 24) subwayStationNum               0.010130
# 25) mallNum                        0.009947
# 26) bankNum                        0.009847
# 27) interSchoolNum                 0.006156
# 28) landMeanPrice                  0.005069
# 29) supplyLandArea                 0.004893
# 30) supplyLandNum                  0.003958
# 31) tradeLandArea                  0.003576
# 32) landTotalPrice                 0.002419
# 33) tradeLandNum                   0.002182

# %%
import matplotlib.pyplot as plt
#plt.title("feature_importance")
#plt.bar(range(x_train.shape[1]),importances[indices],color = "lightblue",align = "center")
#plt.xticks(,feat_labels,rotation = 90)
#plt.xlim([-1,x_train.shape[1]])
#plt.tight_layout()
#ply.show()
#以下代码参考泰坦尼克号案例
fig = plt.figure(figsize=(20,5))
plt.title("feature_importance")
plt.bar(range(x_train.shape[1]), importances[indices],color = "blue",align = "center")
plt.xticks(range(x_train.shape[1]), feat_labels[indices], rotation=45)
plt.show()

# %%
feature =all_df[["area","houseType","houseFloor","totalFloor","houseToward","region","plate","trade_build","shi","ting","wei"]].copy()

# %%
all_dummy_df = pd.get_dummies(feature)
all_dummy_df.head()
# Out:
#              area  houseFloor  totalFloor  trade_build  shi  ting  wei  \
# ID
# 100309852   68.06           0          16           65    2     1    1
# 100307942  125.55           1          14           11    3     2    2
# 100307764  132.00           0          32          148    3     2    2
# 100306518   57.00           1          17          148    1     1    1
# 100305262  129.00           0           2          148    3     2    3
#
#            houseType_0室0厅1卫  houseType_1室0厅0卫  houseType_1室0厅1卫  \
# ID
# 100309852                 0                 0                 0
# 100307942                 0                 0                 0
# 100307764                 0                 0                 0
# 100306518                 0                 0                 0
# 100305262                 0                 0                 0
#
#                ...        plate_BK00057  plate_BK00058  plate_BK00059  \
# ID             ...
# 100309852      ...                    0              0              0
# 100307942      ...                    0              0              0
# 100307764      ...                    0              0              0
# 100306518      ...                    0              0              0
# 100305262      ...                    0              0              0
#
#            plate_BK00060  plate_BK00061  plate_BK00062  plate_BK00063  \
# ID
# 100309852              0              0              0              0
# 100307942              0              0              0              0
# 100307764              0              0              0              0
# 100306518              0              0              0              0
# 100305262              0              0              0              0
#
#            plate_BK00064  plate_BK00065  plate_BK00066
# ID
# 100309852              1              0              0
# 100307942              0              0              0
# 100307764              0              0              0
# 100306518              0              0              0
# 100305262              0              0              0
#
# [5 rows x 204 columns]

# %%
print(y_train.shape)
# Out:
# (40072,)

# %%
dummy_train_df = all_dummy_df.loc[train_1.index]   #one_hot处理后的训练集
dummy_test_df = all_dummy_df.loc[test_1.index]     #one_hot处理后的测试集

# %%
#print(dummy_train_df.shape)
y_train.shape[0]
# Out:
# 40072

# %% [markdown]
# # 建立模型

# %%
X_train, X_test, y_train, y_test = train_test_split(dummy_train_df, y_train, test_size=0.2, random_state=0)
 
model = xgb.XGBRegressor(
    max_depth=5, 
    learning_rate=0.1, 
    n_estimators=160, 
    silent=True, 
    objective='reg:gamma')
model.fit(X_train, y_train)
 
# 对测试集进行预测
ans = model.predict(X_test)
 
# 显示重要特征
plot_importance(model)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \

# %%
y_pro = model.predict(dummy_test_df)

# %%
submission_df = pd.DataFrame(data = y_pro)
#submission_df.head()

# %%
submission_df.to_csv("C:/Users/Administrator/future/output/submit.csv",index =None,header =None)

# %%
submission_df.head(5)
# Out:
#              0
# 0  3651.656494
# 1  4975.159668
# 2  5434.874023
# 3  3722.926270
# 4  5094.716309
